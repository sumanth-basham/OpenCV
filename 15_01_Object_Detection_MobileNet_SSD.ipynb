# %% [markdown]
# <a href="https://colab.research.google.com/github/tillu1208/OpenCV/blob/main/15_01_Object_Detection_MobileNet_SSD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style="font-size:30px;">Deep Learning based Object Detection using MobileNet SSD</h1>
#
# In this chapter, we will discuss how to use Deep Learning based Object Detectors in OpenCV. Faster-RCNN, R-FCN, SSD, and YOLO are among the Object Detection models implemented in OpenCV.
# You can check out the support for various models in the **[Wiki](https://github.com/opencv/opencv/wiki/Deep-Learning-in-OpenCV#object-detection)**.
#
# We will discuss the [Single Shot Multibox Detector (SSD)](https://arxiv.org/pdf/1512.02325.pdf) model trained using the [Tensorflow Object Detection API](https://github.com/tensorflow/models/tree/master/research/object_detection). Among the SSD based models, there is support for MobileNet and Inception as the backbone CNN. They also provide a script to convert the graph configuration to OpenCV format, so that you may train your own models and use them in OpenCV.
#
# As an example, we will be detecting objects in the following image:
#
# <br>
# <center>
# <img src="https://opencv.org/wp-content/uploads/2021/09/c0-m15-fruit-vegetable.jpg" alt="Fruit Vegetable">
# </center>
# <br>
#
# The steps involved in detecting objects using the DNN module are as follows:
# 1. Load the model and input image to memory.
# 1. Detect objects using the forward method of the network.
# 1. Display the detected objects.

# %%
if 'google.colab' in str(get_ipython()):
    print("Downloading Code to Colab Environment")
    # !wget https://www.dropbox.com/sh/uro596fmm67in3b/AABurDoQj5tS94EgUDQXkcBaa?dl=1 -O module-code.zip -q --show-progress
    # !unzip -qq module-code.zip
    # !pip install --upgrade opencv-contrib-python
else:
    pass
# Out:
# Downloading Code to Colab Environment
# module-code.zip     100%[===================>] 141.18M  63.9MB/s    in 2.2s
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-contrib-python) (1.25.2)
# Installing collected packages: opencv-contrib-python
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.8.0.76
#     Uninstalling opencv-contrib-python-4.8.0.76:
#       Successfully uninstalled opencv-contrib-python-4.8.0.76
# Successfully installed opencv-contrib-python-4.9.0.80

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 8.0)
matplotlib.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # 1. Download model
#
# Here we will download the model if it is not present in the local folder. Note: this may take a little while, depending on your internet connection.

# %%
modelFile = 'ssd_mobilenet_frozen_inference_graph.pb'
configFile = 'ssd_mobilenet_v2_coco_2018_03_29.pbtxt'
classFile = 'coco_class_labels.txt'

# %%
import requests
from os import path

if(not path.exists(modelFile)):
    print('Downloading MobileNet SSD Model.......')

    url = 'https://opencv-courses.s3.us-west-2.amazonaws.com/ssd_mobilenet_frozen_inference_graph.pb'

    r = requests.get(url)

    with open(modelFile, 'wb') as f:
        f.write(r.content)

    print('ssd_mobilenet_frozen_inference_graph Download complete!')

# %% [markdown]
# # 2. Read Tensorflow Model
# Here, we read the model specified above into memory.

# %%
# Read the Tensorflow network
net = cv2.dnn.readNetFromTensorflow(modelFile, configFile)

# %% [markdown]
# ## <font style="color:rgb(50,120,229)">Check Class Labels</font>
# We check the class labels which will come handy while decoding the output from the network. This shows the total set of allowable objects the model can detect and classify.

# %%
with open(classFile) as fp:
    labels = fp.read().split('\n')
print(sorted(labels))
# Out:
# ['', 'airplane', 'apple', 'backpack', 'banana', 'baseball bat', 'baseball glove', 'bear', 'bed', 'bench', 'bicycle', 'bird', 'blender', 'boat', 'book', 'bottle', 'bowl', 'broccoli', 'bus', 'cake', 'car', 'carrot', 'cat', 'cell phone', 'chair', 'clock', 'couch', 'cow', 'cup', 'desk', 'dining table', 'dog', 'donut', 'door', 'elephant', 'eye glasses', 'fire hydrant', 'fork', 'frisbee', 'giraffe', 'hair brush', 'hair drier', 'handbag', 'hat', 'horse', 'hot dog', 'keyboard', 'kite', 'knife', 'laptop', 'microwave', 'mirror', 'motorcycle', 'mouse', 'orange', 'oven', 'parking meter', 'person', 'pizza', 'plate', 'potted plant', 'refrigerator', 'remote', 'sandwich', 'scissors', 'sheep', 'shoe', 'sink', 'skateboard', 'skis', 'snowboard', 'spoon', 'sports ball', 'stop sign', 'street sign', 'suitcase', 'surfboard', 'teddy bear', 'tennis racket', 'tie', 'toaster', 'toilet', 'toothbrush', 'traffic light', 'train', 'truck', 'tv', 'umbrella', 'unlabeled', 'vase', 'window', 'wine glass', 'zebra']

# %% [markdown]
# # 3. Detect Objects
# The below function takes in the network and image.
#
# It first preprocesses the input image and then passes it through the network using the `forward` function.
#
# Finally it returns the detected objects.

# %%
def detect_objects(net, img):
    """Run object detection over the input image."""
    # Blob dimension (dim x dim)
    dim = 300

    mean = (0, 0, 0)

    # Create a blob from the image
    blob = cv2.dnn.blobFromImage(img, 1.0, (dim, dim), mean, True)

    # Pass blob to the network
    net.setInput(blob)

    # Peform Prediction
    objects = net.forward()
    return objects

# %%
food_img = cv2.imread('fruit-vegetable.jpg')
food_objects = detect_objects(net, food_img)

# Each detected object returns a list with the structure of:
# [[[..., classId, score, x, y, w, h]]]
print(f'Detected {len(food_objects[0][0])} objects (no confidence filtering)')
first_detected_obj = food_objects[0][0][0]
print('First object:', first_detected_obj)
# Out:
# Detected 100 objects (no confidence filtering)
# First object: [ 0.         57.          0.8886346   0.6576171   0.3315706   0.8071592
#   0.91620326]

# %% [markdown]
# # 4. Display Results

# %% [markdown]
# ## <font style="color:rgb(50,120,229)">4.1 Display Single Prediction</font>
#
# This is just a utility function used for displaying the object class name on the image.

# %%
def draw_text(im, text, x, y):
    """Draws text label at a given x-y position with a black background."""
    fontface = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 0.7
    thickness = 1

    # Get text size
    textSize = cv2.getTextSize(text, fontface, font_scale, thickness)
    dim = textSize[0]
    baseline = textSize[1]

    # Use text size to create a black rectangle.
    cv2.rectangle(im, (x, y), (x + dim[0], y + dim[1] + baseline), (0, 0, 0), cv2.FILLED);
    # Display text inside the rectangle.
    cv2.putText(im, text, (x, y + dim[1]), fontface, font_scale, (0, 255, 255), thickness, cv2.LINE_AA)

# %% [markdown]
# ## <font style="color:rgb(50,120,229)">4.2 Display All Predictions</font>
# This function gets the objects returned from the above function and loops through all the detected objects and draws bounding box around each detected object. It also uses the above utility function for displaying the class name of the detected object.

# %%
def draw_objects(im, objects, threshold = 0.25):
    """Displays a box and text for each detected object exceeding the confidence threshold."""
    rows = im.shape[0]
    cols = im.shape[1]

    # For every detected object.
    for i in range(objects.shape[2]):
        # Find the class and confidence.
        classId = int(objects[0, 0, i, 1])
        score = float(objects[0, 0, i, 2])

        # Recover original cordinates from normalized coordinates
        x = int(objects[0, 0, i, 3] * cols)
        y = int(objects[0, 0, i, 4] * rows)
        w = int(objects[0, 0, i, 5] * cols - x)
        h = int(objects[0, 0, i, 6] * rows - y)
        # Check if the detection is of good quality
        if score > threshold:
            draw_text(im, "{}".format(labels[classId]), x, y)
            cv2.rectangle(im, (x, y), (x + w, y + h), (255, 255, 255), 2)

    # Convert Image to RGB since we are using Matplotlib for displaying image.
    mp_img = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    return mp_img

# %%
result = draw_objects(food_img.copy(), food_objects, 0.4)
plt.figure(figsize=(30, 10)); plt.imshow(result); plt.show();

# %% [markdown]
# ## <font style="color:rgb(50,120,229)">4.3 Comparing confidence thresholds</font>

# %%
traffic_img = cv2.imread('traffic.jpg')
traffic_objects = detect_objects(net, traffic_img)

# Compare displays with low and high confidence thresholds.
low = draw_objects(traffic_img.copy(), traffic_objects, 0.0)
mid = draw_objects(traffic_img.copy(), traffic_objects, 0.3)
high = draw_objects(traffic_img.copy(), traffic_objects, 0.9)

# Display the different thresholds.
plt.figure(figsize = (20, 8))
plt.subplot(131); plt.axis('off'); plt.imshow(low); plt.title('Low confidence')
plt.subplot(132); plt.axis('off'); plt.imshow(mid); plt.title('Medium confidence')
plt.subplot(133); plt.axis('off'); plt.imshow(high); plt.title('High confidence')
# Out:
# Text(0.5, 1.0, 'High confidence')

# %% [markdown]
# # 5. Use a different Model from Tensorflow
# What if you wanted to use a different model from Tensorflow in OpenCV? Just follow the steps given below.
#
# ### <font style="color:rgb(8,133,37)">1. Check out the Tensorflow model ZOO</font>
#
# Model files can be downloaded from the Tensorflow Object Detection Model Zoo
# https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf1_detection_zoo.md
#
# In our case we are using the SSD Mobilenet v2 COCO (ssd_mobilenet_v2_coco).
#
# ### <font style="color:rgb(8,133,37)">2. Download model file</font>
# You can download the model file as a zip archive. For example, for the above example, we download the following file:
# http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_coco_2018_03_29.tar.gz
#
# ### <font style="color:rgb(8,133,37)">Folder Structure </font>
# After you uncompress the zip file, it should look similar to this:
#
# **ssd_mobilenet_v2_coco_2018_03_29** <br>
# |─ checkpoint <br>
# |─ **frozen_inference_graph.pb** <br>
# |─ model.ckpt.data-00000-of-00001 <br>
# |─ model.ckpt.index <br>
# |─ model.ckpt.meta <br>
# |─ pipeline.config <br>
# |─ saved_model <br>
# |─── saved_model.pb <br>
# |─── variables <br>
#
# The "frozen" .pb file is the one that is to be used in OpenCV which contains the frozen weights, meaning it only contains the information needed for inference and thus is the most lightweight.
#
# ### <font style="color:rgb(8,133,37)">3. Create config file from frozen graph</font>
# If you need to create a config file to be used alog with the model file, then just run the [tf_text_graph_ssd.py](https://github.com/opencv/opencv/blob/master/samples/dnn/tf_text_graph_ssd.py) file with input as the path to the frozen_graph.pb file and output as desired.
#
# Once you have the .pb file and .pbtxt file, you should be able to use them in OpenCV.

# %% [markdown]
# # FAQ
#
# ### Batch Size: The batch size in the context of the `cv2.dnn.blobFromImages` function refers to the number of images processed in a single forward pass. However, when interpreting the output of an SSD model, the batch size is not explicitly represented in the `net.forward()` output shape because the detections from all images in the batch are concatenated into a single array.
#
# #### Output Explanation: Suppose we are passing 2 images in batch and got an output shape (1,1,200,7)
#
# * The first **1 in the shape (1, 1, 200, 7)** doesn't refer to the batch size; it's part of the output's dimensions that OpenCV's DNN module uses for its outputs.
# * **The second 1** often is a placeholder or could be part of the network's output dimensionality.
# * **200 **represents the **number of detections** made by the network. SSD models often have a fixed number of potential detections per image, and this number includes both true and false positives, as well as many low-confidence detections.
# * **7** represents the data for each detection, typically including **the batch index (indicating which image in the batch the detection belongs to), class ID, confidence score, and bounding box coordinates (x, y, width, height)**.
#
#
# Given this, if you're processing two images in a batch, the detections for both images are included in this single array. The first value in each detection's array (within the last dimension of size 7) indicates which image in the batch the detection is for **(e.g., 0 for the first image, 1 for the second image, if you're processing two images)**.

# %%
def detect_objects(net, imgs, dim=300):
    """Run object detection over the batch of input images, resizing them to a common dimension and converting detection results."""
    mean = (104.0, 177.0, 123.0)  # Common mean values for pre-processing

    # Resize images to a common size and stack them
    resized_imgs = [cv2.resize(img, (dim, dim)) for img in imgs]
    blob = cv2.dnn.blobFromImages(resized_imgs, scalefactor=1.0, size=(dim, dim), mean=mean, swapRB=True)
    print(blob.shape)

    # Pass blob to the network
    net.setInput(blob)

    # Perform Prediction
    objects = net.forward()

    # Process the output to convert normalized coordinates to pixel coordinates
    detections = []
    for detection in objects[0, 0, :, :]:
        batch_index = int(detection[0])
        class_id = int(detection[1])
        confidence = float(detection[2])
        x_min = int(detection[3] * dim)
        y_min = int(detection[4] * dim)
        x_max = int(detection[5] * dim)
        y_max = int(detection[6] * dim)

        # Append detailed detection info (including pixel coordinates) for each detection
        detections.append({
            'batch_index': batch_index,
            'class_id': class_id,
            'confidence': confidence,
            'bounding_box': (x_min, y_min, x_max, y_max)
        })

    return detections

# %%
# Load images (adjust the paths as necessary)
food_img_test = cv2.imread('fruit-vegetable.jpg')
car_img = cv2.imread('car.jpg')

# Assuming 'net' is already defined and initialized SSD model
# Detect objects
food_objects = detect_objects(net, [food_img_test, car_img])


# Example usage
print(f'Detected {len(food_objects)} objects (with confidence filtering applied externally if desired)')
for obj in food_objects:
    print(f'Batch index: {obj["batch_index"]}, Class ID: {obj["class_id"]}, Confidence: {obj["confidence"]}, Bounding Box: {obj["bounding_box"]}')
# Out:
# (2, 3, 300, 300)
# Detected 200 objects (with confidence filtering applied externally if desired)
# Batch index: 0, Class ID: 57, Confidence: 0.5089399814605713, Bounding Box: (218, 89, 279, 228)
# Batch index: 0, Class ID: 57, Confidence: 0.49795016646385193, Bounding Box: (208, 95, 263, 251)
# Batch index: 0, Class ID: 53, Confidence: 0.42944636940956116, Bounding Box: (151, 244, 231, 299)
# Batch index: 0, Class ID: 53, Confidence: 0.37247544527053833, Bounding Box: (72, 224, 153, 301)
# Batch index: 0, Class ID: 53, Confidence: 0.32988232374191284, Bounding Box: (100, 130, 185, 250)
# Batch index: 0, Class ID: 53, Confidence: 0.3230571746826172, Bounding Box: (0, 192, 47, 298)
# Batch index: 0, Class ID: 53, Confidence: 0.27971816062927246, Bounding Box: (241, 223, 297, 295)
# Batch index: 0, Class ID: 53, Confidence: 0.265753835439682, Bounding Box: (5, 89, 191, 291)
# Batch index: 0, Class ID: 53, Confidence: 0.22254125773906708, Bounding Box: (78, 111, 195, 282)
# Batch index: 0, Class ID: 52, Confidence: 0.20732174813747406, Bounding Box: (41, 5, 145, 178)
# Batch index: 0, Class ID: 53, Confidence: 0.14548209309577942, Bounding Box: (122, 129, 195, 268)
# Batch index: 0, Class ID: 53, Confidence: 0.13661688566207886, Bounding Box: (7, 177, 39, 213)
# Batch index: 0, Class ID: 53, Confidence: 0.13658441603183746, Bounding Box: (8, 12, 285, 296)
# Batch index: 0, Class ID: 58, Confidence: 0.13534869253635406, Bounding Box: (58, 18, 146, 182)
# Batch index: 0, Class ID: 53, Confidence: 0.1220582127571106, Bounding Box: (3, 193, 33, 231)
# Batch index: 0, Class ID: 53, Confidence: 0.11952383071184158, Bounding Box: (-5, 115, 127, 297)
# Batch index: 0, Class ID: 53, Confidence: 0.11615674197673798, Bounding Box: (45, 173, 109, 283)
# Batch index: 0, Class ID: 53, Confidence: 0.11466939747333527, Bounding Box: (9, 192, 285, 292)
# Batch index: 0, Class ID: 57, Confidence: 0.11312904953956604, Bounding Box: (0, 0, 39, 88)
# Batch index: 0, Class ID: 53, Confidence: 0.10911298543214798, Bounding Box: (26, 8, 149, 212)
# Batch index: 0, Class ID: 53, Confidence: 0.10876940935850143, Bounding Box: (272, 193, 301, 275)
# Batch index: 0, Class ID: 53, Confidence: 0.10348165035247803, Bounding Box: (2, 137, 256, 301)
# Batch index: 0, Class ID: 53, Confidence: 0.10158330947160721, Bounding Box: (255, 204, 300, 290)
# Batch index: 0, Class ID: 53, Confidence: 0.09948448091745377, Bounding Box: (0, 167, 16, 200)
# Batch index: 0, Class ID: 53, Confidence: 0.09284178167581558, Bounding Box: (2, 151, 46, 226)
# Batch index: 0, Class ID: 57, Confidence: 0.09178062528371811, Bounding Box: (41, 5, 145, 178)
# Batch index: 0, Class ID: 55, Confidence: 0.09148790687322617, Bounding Box: (0, 135, 19, 169)
# Batch index: 0, Class ID: 53, Confidence: 0.08884283155202866, Bounding Box: (14, 167, 40, 199)
# Batch index: 0, Class ID: 53, Confidence: 0.08815071731805801, Bounding Box: (0, 192, 19, 234)
# Batch index: 0, Class ID: 53, Confidence: 0.087220199406147, Bounding Box: (3, 174, 186, 302)
# Batch index: 0, Class ID: 53, Confidence: 0.08714006096124649, Bounding Box: (0, 177, 74, 303)
# Batch index: 0, Class ID: 53, Confidence: 0.08204901963472366, Bounding Box: (4, 64, 179, 223)
# Batch index: 0, Class ID: 53, Confidence: 0.08081113547086716, Bounding Box: (50, 88, 81, 118)
# Batch index: 0, Class ID: 53, Confidence: 0.08002443611621857, Bounding Box: (1, 17, 161, 263)
# Batch index: 0, Class ID: 58, Confidence: 0.07859697192907333, Bounding Box: (218, 89, 279, 228)
# Batch index: 0, Class ID: 57, Confidence: 0.07837001979351044, Bounding Box: (169, 71, 246, 273)
# Batch index: 0, Class ID: 57, Confidence: 0.07618536800146103, Bounding Box: (10, 69, 38, 103)
# Batch index: 0, Class ID: 52, Confidence: 0.06940783560276031, Bounding Box: (103, 33, 140, 170)
# Batch index: 0, Class ID: 55, Confidence: 0.06870392709970474, Bounding Box: (241, 223, 297, 295)
# Batch index: 0, Class ID: 57, Confidence: 0.06600415706634521, Bounding Box: (0, 68, 12, 110)
# Batch index: 0, Class ID: 57, Confidence: 0.06492377072572708, Bounding Box: (214, 52, 298, 262)
# Batch index: 0, Class ID: 57, Confidence: 0.06186297535896301, Bounding Box: (8, -3, 66, 93)
# Batch index: 0, Class ID: 60, Confidence: 0.060969363898038864, Bounding Box: (245, 84, 297, 205)
# Batch index: 0, Class ID: 55, Confidence: 0.05888032168149948, Bounding Box: (151, 244, 231, 299)
# Batch index: 0, Class ID: 57, Confidence: 0.057230930775403976, Bounding Box: (1, 49, 45, 125)
# Batch index: 0, Class ID: 57, Confidence: 0.05647537484765053, Bounding Box: (45, 10, 93, 85)
# Batch index: 0, Class ID: 57, Confidence: 0.05555615946650505, Bounding Box: (29, 7, 84, 92)
# Batch index: 0, Class ID: 57, Confidence: 0.054650336503982544, Bounding Box: (-2, 63, 55, 110)
# Batch index: 0, Class ID: 52, Confidence: 0.054104652255773544, Bounding Box: (2, 0, 112, 135)
# Batch index: 0, Class ID: 57, Confidence: 0.05395938828587532, Bounding Box: (0, 81, 61, 133)
# Batch index: 0, Class ID: 57, Confidence: 0.05373810604214668, Bounding Box: (4, 2, 77, 69)
# Batch index: 0, Class ID: 55, Confidence: 0.053689029067754745, Bounding Box: (20, 131, 49, 166)
# Batch index: 0, Class ID: 57, Confidence: 0.05340263247489929, Bounding Box: (12, 87, 40, 122)
# Batch index: 0, Class ID: 57, Confidence: 0.053219735622406006, Bounding Box: (192, 103, 233, 250)
# Batch index: 0, Class ID: 57, Confidence: 0.05262776091694832, Bounding Box: (1, 84, 13, 113)
# Batch index: 0, Class ID: 57, Confidence: 0.051817990839481354, Bounding Box: (56, 53, 83, 92)
# Batch index: 0, Class ID: 52, Confidence: 0.051508594304323196, Bounding Box: (79, 42, 110, 174)
# Batch index: 0, Class ID: 57, Confidence: 0.05058472603559494, Bounding Box: (0, 1, 23, 115)
# Batch index: 0, Class ID: 57, Confidence: 0.05054459348320961, Bounding Box: (30, -7, 115, 91)
# Batch index: 0, Class ID: 57, Confidence: 0.05015147477388382, Bounding Box: (26, 45, 51, 93)
# Batch index: 0, Class ID: 57, Confidence: 0.050107985734939575, Bounding Box: (4, 41, 72, 99)
# Batch index: 0, Class ID: 57, Confidence: 0.04901121184229851, Bounding Box: (62, -5, 145, 89)
# Batch index: 0, Class ID: 55, Confidence: 0.048883404582738876, Bounding Box: (40, 105, 64, 141)
# Batch index: 0, Class ID: 55, Confidence: 0.04812951758503914, Bounding Box: (2, 81, 83, 208)
# Batch index: 0, Class ID: 57, Confidence: 0.047276563942432404, Bounding Box: (10, 47, 38, 101)
# Batch index: 0, Class ID: 57, Confidence: 0.045179590582847595, Bounding Box: (26, 78, 49, 103)
# Batch index: 0, Class ID: 57, Confidence: 0.044674865901470184, Bounding Box: (13, 49, 58, 126)
# Batch index: 0, Class ID: 57, Confidence: 0.04432960972189903, Bounding Box: (0, 107, 23, 139)
# Batch index: 0, Class ID: 57, Confidence: 0.04413237050175667, Bounding Box: (55, 34, 87, 80)
# Batch index: 0, Class ID: 57, Confidence: 0.04373544082045555, Bounding Box: (0, 48, 10, 106)
# Batch index: 0, Class ID: 57, Confidence: 0.04367668926715851, Bounding Box: (45, 50, 73, 91)
# Batch index: 0, Class ID: 57, Confidence: 0.04341408982872963, Bounding Box: (8, 97, 38, 135)
# Batch index: 0, Class ID: 57, Confidence: 0.04298711195588112, Bounding Box: (25, 82, 47, 123)
# Batch index: 0, Class ID: 55, Confidence: 0.04267537221312523, Bounding Box: (0, 0, 39, 88)
# Batch index: 0, Class ID: 57, Confidence: 0.042362939566373825, Bounding Box: (-5, 92, 45, 139)
# Batch index: 0, Class ID: 55, Confidence: 0.0423617959022522, Bounding Box: (0, 120, 18, 146)
# Batch index: 0, Class ID: 55, Confidence: 0.04165683686733246, Bounding Box: (13, 153, 41, 180)
# Batch index: 0, Class ID: 55, Confidence: 0.0407547801733017, Bounding Box: (0, 107, 23, 139)
# Batch index: 0, Class ID: 57, Confidence: 0.04028411582112312, Bounding Box: (-13, 47, 40, 97)
# Batch index: 0, Class ID: 57, Confidence: 0.039919108152389526, Bounding Box: (3, -1, 90, 110)
# Batch index: 0, Class ID: 57, Confidence: 0.03975518047809601, Bounding Box: (5, 23, 75, 86)
# Batch index: 0, Class ID: 57, Confidence: 0.038945522159338, Bounding Box: (216, 144, 243, 186)
# Batch index: 0, Class ID: 57, Confidence: 0.03887483850121498, Bounding Box: (26, 40, 87, 97)
# Batch index: 0, Class ID: 55, Confidence: 0.03825345262885094, Bounding Box: (11, 132, 39, 165)
# Batch index: 0, Class ID: 58, Confidence: 0.03806907311081886, Bounding Box: (14, 0, 142, 166)
# Batch index: 0, Class ID: 52, Confidence: 0.03806772828102112, Bounding Box: (194, 1, 232, 102)
# Batch index: 0, Class ID: 57, Confidence: 0.03800785169005394, Bounding Box: (220, 156, 239, 210)
# Batch index: 0, Class ID: 55, Confidence: 0.037834905087947845, Bounding Box: (50, 88, 81, 118)
# Batch index: 0, Class ID: 57, Confidence: 0.03596498817205429, Bounding Box: (180, 110, 211, 243)
# Batch index: 0, Class ID: 57, Confidence: 0.03551967069506645, Bounding Box: (42, 34, 70, 79)
# Batch index: 0, Class ID: 57, Confidence: 0.03544030338525772, Bounding Box: (216, 131, 245, 168)
# Batch index: 0, Class ID: 57, Confidence: 0.035438813269138336, Bounding Box: (39, 37, 101, 94)
# Batch index: 0, Class ID: 60, Confidence: 0.03534100577235222, Bounding Box: (151, 244, 231, 299)
# Batch index: 0, Class ID: 55, Confidence: 0.035333823412656784, Bounding Box: (56, 100, 79, 125)
# Batch index: 0, Class ID: 55, Confidence: 0.03447159752249718, Bounding Box: (62, 71, 84, 103)
# Batch index: 0, Class ID: 58, Confidence: 0.03286246955394745, Bounding Box: (208, 95, 263, 251)
# Batch index: 0, Class ID: 55, Confidence: 0.03244803100824356, Bounding Box: (0, 3, 21, 43)
# Batch index: 0, Class ID: 55, Confidence: 0.0323767364025116, Bounding Box: (9, 123, 33, 148)
# Batch index: 0, Class ID: 32, Confidence: 0.032294753938913345, Bounding Box: (239, 0, 299, 106)
# Batch index: 0, Class ID: 55, Confidence: 0.03086327761411667, Bounding Box: (3, 4, 35, 45)
# Batch index: 1, Class ID: 3, Confidence: 0.9981157779693604, Bounding Box: (37, 138, 211, 226)
# Batch index: 1, Class ID: 1, Confidence: 0.17885789275169373, Bounding Box: (197, 160, 299, 226)
# Batch index: 1, Class ID: 1, Confidence: 0.09244031459093094, Bounding Box: (192, 86, 295, 193)
# Batch index: 1, Class ID: 1, Confidence: 0.0717797502875328, Bounding Box: (131, 156, 142, 170)
# Batch index: 1, Class ID: 16, Confidence: 0.054377492517232895, Bounding Box: (69, 97, 80, 113)
# Batch index: 1, Class ID: 21, Confidence: 0.046710848808288574, Bounding Box: (199, 158, 299, 221)
# Batch index: 1, Class ID: 1, Confidence: 0.04440447315573692, Bounding Box: (180, 119, 291, 221)
# Batch index: 1, Class ID: 1, Confidence: 0.04411890730261803, Bounding Box: (-1, 75, 103, 192)
# Batch index: 1, Class ID: 1, Confidence: 0.0434529148042202, Bounding Box: (146, 158, 158, 171)
# Batch index: 1, Class ID: 1, Confidence: 0.04321750998497009, Bounding Box: (-1, 130, 103, 197)
# Batch index: 1, Class ID: 1, Confidence: 0.04307575523853302, Bounding Box: (98, 146, 114, 163)
# Batch index: 1, Class ID: 1, Confidence: 0.04137346148490906, Bounding Box: (71, 152, 78, 160)
# Batch index: 1, Class ID: 3, Confidence: 0.041123948991298676, Bounding Box: (43, 157, 145, 217)
# Batch index: 1, Class ID: 1, Confidence: 0.040223803371191025, Bounding Box: (211, 56, 295, 178)
# Batch index: 1, Class ID: 38, Confidence: 0.03930933028459549, Bounding Box: (69, 97, 80, 113)
# Batch index: 1, Class ID: 1, Confidence: 0.038908734917640686, Bounding Box: (57, 150, 62, 157)
# Batch index: 1, Class ID: 3, Confidence: 0.03790377080440521, Bounding Box: (41, 160, 104, 227)
# Batch index: 1, Class ID: 1, Confidence: 0.035134270787239075, Bounding Box: (43, 148, 48, 155)
# Batch index: 1, Class ID: 1, Confidence: 0.0341920480132103, Bounding Box: (164, 73, 296, 169)
# Batch index: 1, Class ID: 1, Confidence: 0.03389144316315651, Bounding Box: (0, 138, 8, 155)
# Batch index: 1, Class ID: 1, Confidence: 0.033881694078445435, Bounding Box: (20, 147, 27, 155)
# Batch index: 1, Class ID: 3, Confidence: 0.03215387836098671, Bounding Box: (90, 141, 191, 171)
# Batch index: 1, Class ID: 3, Confidence: 0.031116951256990433, Bounding Box: (44, 146, 140, 186)
# Batch index: 1, Class ID: 3, Confidence: 0.029516948387026787, Bounding Box: (78, 139, 202, 180)
# Batch index: 1, Class ID: 3, Confidence: 0.028812913224101067, Bounding Box: (22, 147, 109, 187)
# Batch index: 1, Class ID: 3, Confidence: 0.027125218883156776, Bounding Box: (24, 153, 232, 247)
# Batch index: 1, Class ID: 1, Confidence: 0.026281658560037613, Bounding Box: (103, 145, 141, 164)
# Batch index: 1, Class ID: 1, Confidence: 0.02621184103190899, Bounding Box: (214, 103, 304, 224)
# Batch index: 1, Class ID: 67, Confidence: 0.0260611679404974, Bounding Box: (43, 220, 297, 298)
# Batch index: 1, Class ID: 1, Confidence: 0.025726977735757828, Bounding Box: (6, 41, 112, 268)
# Batch index: 1, Class ID: 1, Confidence: 0.025090815499424934, Bounding Box: (0, 136, 7, 148)
# Batch index: 1, Class ID: 1, Confidence: 0.024990536272525787, Bounding Box: (211, 107, 300, 300)
# Batch index: 1, Class ID: 1, Confidence: 0.0246262326836586, Bounding Box: (210, -3, 300, 214)
# Batch index: 1, Class ID: 1, Confidence: 0.02452046424150467, Bounding Box: (1, 147, 10, 189)
# Batch index: 1, Class ID: 1, Confidence: 0.024452636018395424, Bounding Box: (194, 43, 275, 185)
# Batch index: 1, Class ID: 1, Confidence: 0.023797625675797462, Bounding Box: (-1, 56, 49, 206)
# Batch index: 1, Class ID: 3, Confidence: 0.023393018171191216, Bounding Box: (37, 188, 234, 247)
# Batch index: 1, Class ID: 1, Confidence: 0.023189876228570938, Bounding Box: (142, 144, 164, 163)
# Batch index: 1, Class ID: 65, Confidence: 0.023142466321587563, Bounding Box: (0, 160, 291, 292)
# Batch index: 1, Class ID: 1, Confidence: 0.02307315729558468, Bounding Box: (1, 129, 90, 294)
# Batch index: 1, Class ID: 1, Confidence: 0.02298189327120781, Bounding Box: (1, 137, 45, 302)
# Batch index: 1, Class ID: 1, Confidence: 0.022905180230736732, Bounding Box: (-3, 119, 73, 210)
# Batch index: 1, Class ID: 1, Confidence: 0.02266656421124935, Bounding Box: (0, 106, 31, 291)
# Batch index: 1, Class ID: 1, Confidence: 0.022613048553466797, Bounding Box: (-1, 91, 48, 244)
# Batch index: 1, Class ID: 1, Confidence: 0.022478662431240082, Bounding Box: (88, 152, 96, 160)
# Batch index: 1, Class ID: 1, Confidence: 0.0222991444170475, Bounding Box: (-3, 103, 126, 180)
# Batch index: 1, Class ID: 1, Confidence: 0.021634113043546677, Bounding Box: (1, 124, 19, 218)
# Batch index: 1, Class ID: 3, Confidence: 0.02136017009615898, Bounding Box: (106, 148, 209, 210)
# Batch index: 1, Class ID: 1, Confidence: 0.021129904314875603, Bounding Box: (200, 159, 206, 169)
# Batch index: 1, Class ID: 1, Confidence: 0.021121829748153687, Bounding Box: (154, 178, 162, 185)
# Batch index: 1, Class ID: 1, Confidence: 0.020824356004595757, Bounding Box: (230, 83, 303, 187)
# Batch index: 1, Class ID: 1, Confidence: 0.020695989951491356, Bounding Box: (200, 158, 204, 163)
# Batch index: 1, Class ID: 1, Confidence: 0.020682917907834053, Bounding Box: (155, 156, 178, 170)
# Batch index: 1, Class ID: 1, Confidence: 0.020288977771997452, Bounding Box: (151, 144, 176, 164)
# Batch index: 1, Class ID: 1, Confidence: 0.020245565101504326, Bounding Box: (115, 144, 149, 165)
# Batch index: 1, Class ID: 1, Confidence: 0.019861308857798576, Bounding Box: (2, 90, 90, 247)
# Batch index: 1, Class ID: 3, Confidence: 0.019440120086073875, Bounding Box: (67, 159, 83, 173)
# Batch index: 1, Class ID: 3, Confidence: 0.01935153640806675, Bounding Box: (53, 178, 65, 191)
# Batch index: 1, Class ID: 16, Confidence: 0.01906382478773594, Bounding Box: (40, 85, 136, 118)
# Batch index: 1, Class ID: 38, Confidence: 0.01896536350250244, Bounding Box: (22, 116, 28, 125)
# Batch index: 1, Class ID: 28, Confidence: 0.01690387912094593, Bounding Box: (10, 141, 75, 194)
# Batch index: 1, Class ID: 67, Confidence: 0.016811219975352287, Bounding Box: (17, 189, 289, 293)
# Batch index: 1, Class ID: 3, Confidence: 0.016180045902729034, Bounding Box: (86, 172, 204, 219)
# Batch index: 1, Class ID: 16, Confidence: 0.016072208061814308, Bounding Box: (85, 114, 89, 120)
# Batch index: 1, Class ID: 3, Confidence: 0.015923472121357918, Bounding Box: (46, 180, 124, 229)
# Batch index: 1, Class ID: 28, Confidence: 0.015703869983553886, Bounding Box: (2, 138, 103, 177)
# Batch index: 1, Class ID: 16, Confidence: 0.015651648864150047, Bounding Box: (69, 103, 78, 116)
# Batch index: 1, Class ID: 3, Confidence: 0.01562204584479332, Bounding Box: (64, 140, 158, 172)
# Batch index: 1, Class ID: 3, Confidence: 0.01484325435012579, Bounding Box: (73, 155, 100, 170)
# Batch index: 1, Class ID: 16, Confidence: 0.014838374219834805, Bounding Box: (56, 114, 63, 121)
# Batch index: 1, Class ID: 3, Confidence: 0.014272022061049938, Bounding Box: (88, 152, 96, 160)
# Batch index: 1, Class ID: 16, Confidence: 0.014016753993928432, Bounding Box: (66, 89, 162, 117)
# Batch index: 1, Class ID: 16, Confidence: 0.013982928358018398, Bounding Box: (25, 83, 110, 121)
# Batch index: 1, Class ID: 16, Confidence: 0.013745958916842937, Bounding Box: (78, 83, 92, 92)
# Batch index: 1, Class ID: 62, Confidence: 0.013524150475859642, Bounding Box: (274, 228, 302, 313)
# Batch index: 1, Class ID: 3, Confidence: 0.013520173728466034, Bounding Box: (103, 145, 141, 164)
# Batch index: 1, Class ID: 3, Confidence: 0.013174367137253284, Bounding Box: (67, 178, 81, 189)
# Batch index: 1, Class ID: 67, Confidence: 0.013155057094991207, Bounding Box: (135, 223, 330, 302)
# Batch index: 1, Class ID: 55, Confidence: 0.01254868321120739, Bounding Box: (288, 178, 299, 221)
# Batch index: 1, Class ID: 16, Confidence: 0.012529960833489895, Bounding Box: (184, 263, 194, 267)
# Batch index: 1, Class ID: 62, Confidence: 0.012434466741979122, Bounding Box: (252, 252, 313, 297)
# Batch index: 1, Class ID: 16, Confidence: 0.012417269870638847, Bounding Box: (216, 245, 221, 249)
# Batch index: 1, Class ID: 16, Confidence: 0.01225230935961008, Bounding Box: (201, 269, 207, 271)
# Batch index: 1, Class ID: 62, Confidence: 0.01224702037870884, Bounding Box: (179, 4, 285, 42)
# Batch index: 1, Class ID: 16, Confidence: 0.012040408328175545, Bounding Box: (148, 247, 158, 251)
# Batch index: 1, Class ID: 16, Confidence: 0.011864799074828625, Bounding Box: (39, 69, 133, 105)
# Batch index: 1, Class ID: 3, Confidence: 0.01172834075987339, Bounding Box: (6, 172, 81, 217)
# Batch index: 1, Class ID: 62, Confidence: 0.0116885956376791, Bounding Box: (249, 220, 300, 300)
# Batch index: 1, Class ID: 3, Confidence: 0.011682853102684021, Bounding Box: (24, 137, 165, 204)
# Batch index: 1, Class ID: 38, Confidence: 0.011650117114186287, Bounding Box: (40, 115, 47, 125)
# Batch index: 1, Class ID: 16, Confidence: 0.01156558282673359, Bounding Box: (237, 112, 255, 131)
# Batch index: 1, Class ID: 53, Confidence: 0.011535298079252243, Bounding Box: (236, 73, 258, 93)
# Batch index: 1, Class ID: 3, Confidence: 0.011528127826750278, Bounding Box: (71, 154, 200, 204)
# Batch index: 1, Class ID: 3, Confidence: 0.011502422392368317, Bounding Box: (36, 162, 83, 229)
# Batch index: 1, Class ID: 3, Confidence: 0.011118358001112938, Bounding Box: (36, 139, 132, 173)
# Batch index: 1, Class ID: 16, Confidence: 0.011088231578469276, Bounding Box: (136, 247, 142, 251)
# Batch index: 1, Class ID: 16, Confidence: 0.011029453948140144, Bounding Box: (40, 115, 47, 125)
# Batch index: 1, Class ID: 67, Confidence: 0.01099640317261219, Bounding Box: (225, 250, 304, 298)
# Batch index: 1, Class ID: 28, Confidence: 0.010896996594965458, Bounding Box: (2, 38, 89, 75)
# Batch index: 1, Class ID: 16, Confidence: 0.010815765708684921, Bounding Box: (76, 102, 88, 112)
